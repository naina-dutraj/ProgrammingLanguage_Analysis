# %% [markdown]
# <a href="https://colab.research.google.com/github/naina-dutraj/ProgrammingLanguage_Analysis/blob/main/ProgrammingL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import statements
import pandas as pd

# %% [markdown]
# **Data Exploration**

# %%
df=pd.read_csv('QR.csv', names=['DATE','TAG','POST'],header=0)
df.head()
# Out:
#                   DATE       TAG  POST
# 0  2008-07-01 00:00:00        c#     3
# 1  2008-08-01 00:00:00  assembly     8
# 2  2008-08-01 00:00:00         c    83
# 3  2008-08-01 00:00:00        c#   505
# 4  2008-08-01 00:00:00       c++   164

# %%
df.tail()
# Out:
#                      DATE     TAG   POST
# 2407  2023-01-01 00:00:00     php   3417
# 2408  2023-01-01 00:00:00  python  19027
# 2409  2023-01-01 00:00:00       r   3835
# 2410  2023-01-01 00:00:00    ruby    381
# 2411  2023-01-01 00:00:00   swift   1544

# %%
df.shape
# Out:
# (2412, 3)

# %% [markdown]
# Number of entries in each column of the dataframe

# %%
df.count()
# Out:
# DATE    2412
# TAG     2412
# POST    2412
# dtype: int64

# %%
df.groupby('TAG').sum()
# Out:
# <ipython-input-28-e0b10c91de87>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('TAG').sum()
#                POST
# TAG
# assembly      42127
# c            392287
# c#          1578270
# c++          786942
# delphi        50482
# go            67172
# java        1883729
# javascript  2468156
# perl          67450
# php         1453393
# python      2094494
# r            478925
# ruby         227129
# swift        323708

# %% [markdown]
# Programming Language with the highest number of post is Javascript

# %%
df.groupby('TAG').count()
# Out:
#             DATE  POST
# TAG
# assembly     174   174
# c            174   174
# c#           175   175
# c++          174   174
# delphi       174   174
# go           159   159
# java         174   174
# javascript   174   174
# perl         174   174
# php          174   174
# python       174   174
# r            172   172
# ruby         174   174
# swift        166   166

# %% [markdown]
# swift count is lowest

# %% [markdown]
# Data Cleaning

# %%
from datetime import datetime
df.DATE=pd.to_datetime(df.DATE)#string to datetime object
df.head()
# Out:
#         DATE       TAG  POST
# 0 2008-07-01        c#     3
# 1 2008-08-01  assembly     8
# 2 2008-08-01         c    83
# 3 2008-08-01        c#   505
# 4 2008-08-01       c++   164

# %% [markdown]
# Data Manipulation

# %%
reshaped_df = df.pivot(index='DATE', columns='TAG',values='POST')
reshaped_df
# Out:
# TAG         assembly       c      c#     c++  delphi     go    java  \
# DATE
# 2008-07-01       NaN     NaN     3.0     NaN     NaN    NaN     NaN
# 2008-08-01       8.0    83.0   505.0   164.0    14.0    NaN   222.0
# 2008-09-01      28.0   319.0  1642.0   754.0   104.0    NaN  1129.0
# 2008-10-01      16.0   302.0  1988.0   807.0   112.0    NaN  1149.0
# 2008-11-01      17.0   259.0  1730.0   734.0   141.0    NaN   956.0
# ...              ...     ...     ...     ...     ...    ...     ...
# 2022-09-01     191.0  1646.0  5722.0  3084.0   148.0  841.0  6235.0
# 2022-10-01     242.0  2010.0  5812.0  3213.0   153.0  741.0  6501.0
# 2022-11-01     288.0  2187.0  6064.0  3317.0   116.0  753.0  6813.0
# 2022-12-01     284.0  1869.0  5358.0  2881.0    87.0  635.0  6016.0
# 2023-01-01     254.0  1565.0  5612.0  2817.0   116.0  773.0  6074.0
#
# TAG         javascript   perl     php   python       r   ruby   swift
# DATE
# ...

# %%
reshaped_df.shape
# Out:
# (175, 14)

# %%
reshaped_df.head()
# Out:
# TAG         assembly      c      c#    c++  delphi  go    java  javascript  \
# DATE
# 2008-07-01       NaN    NaN     3.0    NaN     NaN NaN     NaN         NaN
# 2008-08-01       8.0   83.0   505.0  164.0    14.0 NaN   222.0       163.0
# 2008-09-01      28.0  319.0  1642.0  754.0   104.0 NaN  1129.0       634.0
# 2008-10-01      16.0  302.0  1988.0  807.0   112.0 NaN  1149.0       723.0
# 2008-11-01      17.0  259.0  1730.0  734.0   141.0 NaN   956.0       580.0
#
# TAG          perl    php  python    r   ruby  swift
# DATE
# 2008-07-01    NaN    NaN     NaN  NaN    NaN    NaN
# 2008-08-01   28.0  158.0   120.0  NaN   70.0    NaN
# 2008-09-01  130.0  476.0   536.0  6.0  287.0    NaN
# 2008-10-01  127.0  611.0   507.0  NaN  247.0    NaN
# 2008-11-01   97.0  500.0   450.0  1.0  158.0    NaN

# %%
reshaped_df.tail()
# Out:
# TAG         assembly       c      c#     c++  delphi     go    java  \
# DATE
# 2022-09-01     191.0  1646.0  5722.0  3084.0   148.0  841.0  6235.0
# 2022-10-01     242.0  2010.0  5812.0  3213.0   153.0  741.0  6501.0
# 2022-11-01     288.0  2187.0  6064.0  3317.0   116.0  753.0  6813.0
# 2022-12-01     284.0  1869.0  5358.0  2881.0    87.0  635.0  6016.0
# 2023-01-01     254.0  1565.0  5612.0  2817.0   116.0  773.0  6074.0
#
# TAG         javascript   perl     php   python       r   ruby   swift
# DATE
# 2022-09-01     14249.0   82.0  3380.0  20168.0  4020.0  474.0  1798.0
# 2022-10-01     14090.0   82.0  3370.0  22073.0  4530.0  436.0  1630.0
# 2022-11-01     14388.0  110.0  3370.0  22942.0  4636.0  466.0  1681.0
# 2022-12-01     12596.0   95.0  2913.0  19410.0  3695.0  397.0  1472.0
# 2023-01-01     12889.0   77.0  3417.0  19027.0  3835.0  381.0  1544.0

# %%
reshaped_df.count()
# Out:
# TAG
# assembly      174
# c             174
# c#            175
# c++           174
# delphi        174
# go            159
# java          174
# javascript    174
# perl          174
# php           174
# python        174
# r             172
# ruby          174
# swift         166
# dtype: int64

# %%
reshaped_df.columns
# Out:
# Index(['assembly', 'c', 'c#', 'c++', 'delphi', 'go', 'java', 'javascript',
#        'perl', 'php', 'python', 'r', 'ruby', 'swift'],
#       dtype='object', name='TAG')

# %% [markdown]
# Data Visualizations with matplotlib

# %%
reshaped_df.fillna(0, inplace=True)
reshaped_df.head()
reshaped_df.isna().values.any()
# Out:
# False

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.ylim(0, 35000)
for column in reshaped_df.columns:
  plt.plot(reshaped_df.index, reshaped_df[column],linewidth=3, label=reshaped_df[column].name)

  plt.legend(fontsize=16)

# %%
roll_df = reshaped_df.rolling(window=6).mean()

plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.ylim(0, 35000)

# plot the roll_df instead
for column in roll_df.columns:
    plt.plot(roll_df.index, roll_df[column],
             linewidth=3, label=roll_df[column].name)

plt.legend(fontsize=16)

# %% [markdown]
# # From the data we can see rise in python, javascript, java and ruby
